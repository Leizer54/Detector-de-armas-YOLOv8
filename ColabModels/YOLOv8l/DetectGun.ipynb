# %% [markdown]
# <a href="https://colab.research.google.com/github/Leizer54/Detector-de-armas-YOLOv8/blob/main/ColabModels/YOLOv8l/DetectGun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Oct 23 08:39:30 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/MyDrive/SisDetect/DetectGun'

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 27.1/166.8 GB disk)

# %%
# %cd '/content/gdrive/MyDrive/SisDetect'
# Out:
# /content/gdrive/MyDrive/SisDetect

# %%
# !ls
# Out:
# data.yaml  DetectGun.ipynb  test  train  valid	YOLOv8l

# %%
import os

from ultralytics import YOLO

# %%
# %cd '/content/gdrive/MyDrive/SisDetect'
# Out:
# /content/gdrive/MyDrive/SisDetect

# %%
from ultralytics import YOLO

# Use the model
# !yolo train model=yolov8l.pt data="data.yaml" epochs=100 batch=4 imgsz=640 optimizer="Adam"  # train the model
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 259MB/s]
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('/content/gdrive/MyDrive/SisDetect/runs/detect/train/weights/best.pt')  # load a partially trained model

# Resume training
results = model.train(resume=True)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py", line 576, in check_resume
#     if not Path(ckpt_args['data']).exists():
#   File "/usr/lib/python3.10/pathlib.py", line 1290, in exists
#     self.stat()
#   File "/usr/lib/python3.10/pathlib.py", line 1097, in stat
#     return self._accessor.stat(self, follow_symlinks=follow_symlinks)
# OSError: [Errno 107] Transport endpoint is not connected: 'data.yaml'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
# ...

# %%
from ultralytics import YOLO
# !yolo detect mode=val model=/content/gdrive/MyDrive/SisDetect/runs/detect/train/weights/best.pt data=/content/gdrive/MyDrive/SisDetect/data.yaml save=True
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43607379 parameters, 0 gradients, 164.8 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 28.9MB/s]
# val: Scanning /content/gdrive/MyDrive/SisDetect/valid/labels.cache... 741 images, 51 backgrounds, 0 corrupt: 100% 741/741 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 47/47 [00:38<00:00,  1.21it/s]
#                    all        741        783      0.752      0.609       0.69       0.48
# Speed: 1.5ms preprocess, 33.8ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo detect mode=predict model=/content/gdrive/MyDrive/SisDetect/runs/detect/train/weights/best.pt conf=0.25 source=/content/gdrive/MyDrive/SisDetect/test/images save=True
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43607379 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/372 /content/gdrive/MyDrive/SisDetect/test/images/armas-1000-jpg_jpg.rf.d6f735e3207b3badbec2d07b6cd1ed9d.jpg: 640x640 1 pistol, 62.9ms
# image 2/372 /content/gdrive/MyDrive/SisDetect/test/images/armas-1010-jpg_jpg.rf.72eb267fe1604e20014b36b235aa33a5.jpg: 640x640 1 pistol, 63.0ms
# image 3/372 /content/gdrive/MyDrive/SisDetect/test/images/armas-1017-jpg_jpg.rf.25a4a3b9a467b0082a5298cfff37e66c.jpg: 640x640 (no detections), 62.9ms
# image 4/372 /content/gdrive/MyDrive/SisDetect/test/images/armas-1053-jpg_jpg.rf.33f824f6ae3760de651ce2ea11a84757.jpg: 640x640 (no detections), 64.2ms
# image 5/372 /content/gdrive/MyDrive/SisDetect/test/images/armas-1058-jpg_jpg.rf.24367295a81c443b353b64a1f520e837.jpg: 640x640 1 pistol, 63.7ms
# ...

# %%
# !scp -r /content/runs '/content/gdrive/MyDrive/SisDetect'
