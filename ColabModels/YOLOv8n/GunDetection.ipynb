# %% [markdown]
# <a href="https://colab.research.google.com/github/Leizer54/Detector-de-armas-YOLOv8/blob/main/ColabModels/YOLOv8n/GunDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Nov 13 17:07:17 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/MyDrive/SisDetect/DetectGun'

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 27.0/166.8 GB disk)

# %%
# %cd /content/gdrive/MyDrive/GunDetectionMCD.v3i.yolov8
# Out:
# /content/gdrive/MyDrive/GunDetectionMCD.v3i.yolov8

# %%
# !ls
# Out:
# data.yaml  GunDetection.ipynb  runs  test  train  valid  yolov8n.pt

# %%
import os

from ultralytics import YOLO

# %%
from ultralytics import YOLO

# Use the model
# !yolo train model=yolov8n.pt data="data.yaml" epochs=700 batch=16 imgsz=640 optimizer="SGD"  # train the model
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 239MB/s]
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
from ultralytics import YOLO

# !yolo train resume model=/content/gdrive/MyDrive/GunDetectionMCD.v3i.yolov8/runs/detect/train/weights/best.pt
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

# !yolo train resume model=/content/gdrive/MyDrive/GunDetectionMCD.v3i.yolov8/runs/detect/train/weights/best.pt
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

# !yolo train resume model=/content/gdrive/MyDrive/GunDetectionMCD.v3i.yolov8/runs/detect/train/weights/best.pt
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
# !yolo detect mode=val model=/content/gdrive/MyDrive/GunDetectionMCD.v3i.yolov8/runs/detect/train/weights/best.pt data=/content/gdrive/MyDrive/GunDetectionMCD.v3i.yolov8/data.yaml save=True
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/gdrive/MyDrive/GunDetectionMCD.v3i.yolov8/valid/labels.cache... 944 images, 0 backgrounds, 0 corrupt: 100% 944/944 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 59/59 [00:08<00:00,  6.68it/s]
#                    all        944       1056      0.927      0.889      0.929      0.675
# Speed: 0.4ms preprocess, 3.8ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo detect mode=predict model=/content/gdrive/MyDrive/GunDetectionMCD.v3i.yolov8/runs/detect/train/weights/best.pt source=/content/gdrive/MyDrive/GunDetectionMCD.v3i.yolov8/test/images save=True
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/945 /content/gdrive/MyDrive/GunDetectionMCD.v3i.yolov8/test/images/105_jpeg_jpg.rf.db4e6026ee801fe6eb38296a06e5e10a.jpg: 640x640 1 Arma, 7.5ms
# image 2/945 /content/gdrive/MyDrive/GunDetectionMCD.v3i.yolov8/test/images/109_jpeg_jpg.rf.495da48ab4eb5842bd2cbd846304a337.jpg: 640x640 1 Arma, 7.3ms
# image 3/945 /content/gdrive/MyDrive/GunDetectionMCD.v3i.yolov8/test/images/112_jpeg_jpg.rf.7d1aa1ebec4136b13983109f29d94ea1.jpg: 640x640 1 Arma, 8.8ms
# image 4/945 /content/gdrive/MyDrive/GunDetectionMCD.v3i.yolov8/test/images/113_jpg.rf.75dfb30b5f252d1bcdf46e7ae7780968.jpg: 640x640 1 Arma, 7.3ms
# image 5/945 /content/gdrive/MyDrive/GunDetectionMCD.v3i.yolov8/test/images/115_jpeg_jpg.rf.2abf46afef5ea575566b69c6119d62fd.jpg: 640x640 1 Arma, 9.3ms
# ...
