# %% [markdown]
# <a href="https://colab.research.google.com/github/Leizer54/Detector-de-armas-YOLOv8/blob/main/ColabModels/YOLOv8s/DetectorYOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Oct 23 15:00:13 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    23W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ROOT_DIR = '/content/gdrive/MyDrive/SisDetect/DetectGun'

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 27.5/166.8 GB disk)

# %%
# %cd /content/gdrive/MyDrive/SisDetectYOLOv8s
# Out:
# /content/gdrive/MyDrive/SisDetectYOLOv8s

# %%
# !ls
# Out:
# data.yaml  DetectGun.ipynb  runs  test	train  valid  yolov8n.pt  yolov8s.pt

# %%
import os

from ultralytics import YOLO

# %%
from ultralytics import YOLO

# Use the model
# !yolo train model=yolov8s.pt data="data.yaml" epochs=200 batch=4 imgsz=640 optimizer="Adam"  # train the model
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 162MB/s]
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
from ultralytics import YOLO

# !yolo train resume model=/content/gdrive/MyDrive/SisDetectYOLOv8s/runs/detect/train/weights/best.pt
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
from ultralytics import YOLO
# !yolo detect mode=val model=/content/gdrive/MyDrive/SisDetect/runs/detect/train/weights/best.pt data=/content/gdrive/MyDrive/SisDetect/data.yaml save=True
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 268 layers, 43607379 parameters, 0 gradients, 164.8 GFLOPs
# val: Scanning /content/gdrive/MyDrive/SisDetect/valid/labels.cache... 741 images, 51 backgrounds, 0 corrupt: 100% 741/741 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 47/47 [00:12<00:00,  3.80it/s]
#                    all        741        783      0.796      0.648      0.734       0.52
# Speed: 0.4ms preprocess, 10.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo detect mode=predict model=/content/gdrive/MyDrive/SisDetect/runs/detect/train/weights/best.pt conf=0.25 source=/content/gdrive/MyDrive/SisDetect/test/images save=True
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 268 layers, 43607379 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/372 /content/gdrive/MyDrive/SisDetect/test/images/armas-1000-jpg_jpg.rf.d6f735e3207b3badbec2d07b6cd1ed9d.jpg: 640x640 1 pistol, 14.1ms
# image 2/372 /content/gdrive/MyDrive/SisDetect/test/images/armas-1010-jpg_jpg.rf.72eb267fe1604e20014b36b235aa33a5.jpg: 640x640 1 pistol, 14.1ms
# image 3/372 /content/gdrive/MyDrive/SisDetect/test/images/armas-1017-jpg_jpg.rf.25a4a3b9a467b0082a5298cfff37e66c.jpg: 640x640 (no detections), 14.1ms
# image 4/372 /content/gdrive/MyDrive/SisDetect/test/images/armas-1053-jpg_jpg.rf.33f824f6ae3760de651ce2ea11a84757.jpg: 640x640 1 pistol, 15.4ms
# image 5/372 /content/gdrive/MyDrive/SisDetect/test/images/armas-1058-jpg_jpg.rf.24367295a81c443b353b64a1f520e837.jpg: 640x640 1 pistol, 14.3ms
# ...

# %%
# !scp -r /content/runs '/content/gdrive/MyDrive/SisDetect'
